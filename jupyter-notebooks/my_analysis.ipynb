# %% [markdown]
# # [Data 198] Assignment 0 - Git Activity

# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
df = pd.read_csv("/Users/landinh/Desktop/Data198-SP23/data/MOCK_DATA.csv")
df
# Out:
#      id first_name last_name                       email       gender  \
# 0     1     Denise     Arnow      darnow0@soundcloud.com       Female
# 1     2      Lenee    Clague   lclague1@miitbeian.gov.cn       Female
# 2     3    Freemon     Fisby         ffisby2@skyrock.com         Male
# 3     4     Loydie  Kinnaird        lkinnaird3@weibo.com         Male
# 4     5     Cedric      Wink            cwink4@hc360.com         Male
# ..  ...        ...       ...                         ...          ...
# 95   96   Henrieta   Whiston     hwhiston2n@gravatar.com       Female
# 96   97     Karlis   Crocker  kcrocker2o@bizjournals.com         Male
# 97   98    Osbourn     Large          olarge2p@patch.com         Male
# 98   99       Abbe   Redsall        aredsall2q@youku.com  Genderfluid
# 99  100    Catrina  Peniello       cpeniello2r@jimdo.com       Female
#
#          ip_address
# 0    173.47.250.167
# 1     254.10.78.105
# 2     60.190.142.45
# 3   135.150.179.225
# ...
